# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("Vision"):
  os.makedirs("Vision")

# %%
# %cd Vision
# Out:
# /content/gdrive/MyDrive/Vision

# %%
# !pwd #know your location
# Out:
# /content/gdrive/MyDrive/Vision

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
#!wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
#installing mode yolov7

# %%
# %cd yolov7
# Out:
# /content/gdrive/MyDrive/Vision/yolov7

# %%
#!python3 train.py --device 0 --batch-size 16 --epochs 100 --img 640 640 --data data/pedestrian.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-pedestrian.yaml --weights yolov7.pt --name yolov7-pedestrian

# %%
# !python3 detect.py --weights best.pt --conf 0.4 --img-size 640 --source video.mp4
# Out:
# Namespace(weights=['best.pt'], source='video.mp4', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36487166 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
